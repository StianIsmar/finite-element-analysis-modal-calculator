# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def load_csv(path):
    df1 = pd.read_csv(path)
    return df1

def scale_points(dataframe):
    # New column:
    dataframe['magnitude'] = 1
    dataframe.columns.values[0] = "0"
    dataframe.columns.values[1] = "1"
    dataframe.columns.values[2] = "2"
    columns = dataframe.loc[:,'1':'2']
    
    # Calculate the absolute value of the complex numbers:
    magnitude = []
    for row in columns.iterrows():
        index, data = row
        num = (np.sqrt(([data[0]**2+ data[1]**2])))
        
        #Scaling (2G), multiply each float with 1962:
        num[0] = num[0]*1962
        magnitude.append(num[0])
    x = dataframe.loc[:,'0']
    x= x.tolist()
    return x, magnitude
        
d1 = load_csv('./Transmissability_Results/x/X_X.csv')
x, x_x = scale_points(d1)

d1 = load_csv('./Transmissability_Results/x/X_Y.csv')
x, x_y = scale_points(d1)

d1 = load_csv('./Transmissability_Results/x/X_Z.csv')
x, x_z = scale_points(d1)


###### In X-dir
plot_data4(x,x_x,x_y,x_z,"X")


d1 = load_csv('./Transmissability_Results/y/Y_X.csv')
x,x_x = scale_points(d1)

d1 = load_csv('./Transmissability_Results/y/Y_Y.csv')
x,x_y = scale_points(d1)

d1 = load_csv('./Transmissability_Results/y/Y_Z.csv')
x,x_z = scale_points(d1)

###### In Y-dir
plot_data4(x,x_x,x_y,x_z,"Y")

d1 = load_csv('./Transmissability_Results/z/Z_X.csv')
x,x_x = scale_points(d1)

d1 = load_csv('./Transmissability_Results/z/Z_Y.csv')
x,x_y = scale_points(d1)

d1 = load_csv('./Transmissability_Results/z/Z_Z.csv')
x,x_z = scale_points(d1)

###### In Z-dir
plot_data4(x,x_x,x_y,x_z,"Z")

# %%
def plot_data4(x,y1,y2,y3,DIR):
    
    #Creates two subplots and unpacks the output array immediately
    f, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(14,5),gridspec_kw = {'width_ratios':[3, 3,3]})
    st = f.suptitle("Transmissability analysis. Input direction " +  DIR+": Bottom node", fontsize="x-large",y=1.02)
    f.autolayout : True
    figure.autolayout : True


    ax1.grid(linestyle='-', linewidth=0.5)
    ax2.grid(linestyle='-', linewidth=0.5)
    ax3.grid(linestyle='-', linewidth=0.5)


    
    ax1.plot(x, y1,color= 'tab:red')
    ax1.set_title('X-direction', color= 'tab:red')
    
    ax2.plot(x, y2,color= 'tab:brown')
    ax2.set_title('Y-direction',color= 'tab:brown')
    
    ax3.plot(x, y3,color= 'tab:blue')
    ax3.set_title('Z-direction',color= 'tab:blue')
    
    
    f.text(0.5, 0, 'Frequency [Hz]', ha='center')
    f.text(-0.01, 0.5, 'Acceleration/Acceleration [mm/s^2/mm/s^2], Scaled to 2G', va='center', rotation='vertical')
    plt.tight_layout()
    
    f.savefig('Transmis'+DIR+'.png', format='png', dpi=1200)

    
    plt.show()

# %%
d1 = load_csv('./Transmissability_Results/x/X_X.csv')
x, x_x = scale_points(d1)
d1
# Out:
#                 0         1             2  magnitude
# 0        0.343259  1.000000 -2.230728e-11          1
# 1        0.686518  1.000002 -1.784592e-10          1
# 2        1.029777  1.000003 -6.023056e-10          1
# 3        1.373036  1.000006 -1.427706e-09          1
# 4        1.716295  1.000010 -2.788537e-09          1
# 5        2.059555  1.000014 -4.818690e-09          1
# 6        2.402814  1.000019 -7.652091e-09          1
# 7        2.746073  1.000024 -1.142268e-08          1
# 8        3.089332  1.000031 -1.626446e-08          1
# 9        3.432591  1.000038 -2.231144e-08          1
# 10       3.775850  1.000046 -2.969771e-08          1
# 11       4.119109  1.000055 -3.855736e-08          1
# 12       4.462368  1.000065 -4.902460e-08          1
# 13       4.805627  1.000075 -6.123367e-08          1
# 14       5.148887  1.000086 -7.531886e-08          1
# 15       5.492146  1.000098 -9.141452e-08          1
# 16       5.835404  1.000111 -1.096551e-07          1
# 17       6.178664  1.000124 -1.301752e-07          1
# 18       6.521923  1.000138 -1.531094e-07          1
# 19       6.865182  1.000153 -1.785924e-07          1
# 20       7.208441  1.000169 -2.067590e-07          1
# 21       7.551700  1.000185 -2.377442e-07          1
# 22       7.894959  1.000203 -2.716828e-07          1
# 23       8.238218  1.000221 -3.087101e-07          1
# 24       8.581477  1.000239 -3.489613e-07          1
# 25       8.924736  1.000259 -3.925717e-07          1
# 26       9.267996  1.000279 -4.396770e-07          1
# 27       9.611255  1.000300 -4.904126e-07          1
# 28       9.954514  1.000322 -5.449141e-07          1
# 29      10.297770  1.000345 -6.033180e-07          1
# ...           ...       ...           ...        ...
# 3619   970.319200  0.532613 -1.177484e-02          1
# 3620   971.327600  0.532761 -1.175518e-02          1
# 3621   972.337500  0.532908 -1.173555e-02          1
# 3622   973.348000  0.533055 -1.171599e-02          1
# 3623   974.360000  0.533201 -1.169646e-02          1
# 3624   975.372600  0.533347 -1.167700e-02          1
# 3625   976.386800  0.533493 -1.165758e-02          1
# 3626   977.402000  0.533638 -1.163820e-02          1
# 3627   978.417700  0.533782 -1.161889e-02          1
# 3628   979.435000  0.533927 -1.159961e-02          1
# 3629   980.452800  0.534071 -1.158039e-02          1
# 3630   981.472300  0.534214 -1.156121e-02          1
# 3631   982.492200  0.534357 -1.154209e-02          1
# 3632   983.513800  0.534500 -1.152301e-02          1
# 3633   984.536400  0.534643 -1.150398e-02          1
# 3634   985.559500  0.534785 -1.148501e-02          1
# 3635   986.584300  0.534927 -1.146607e-02          1
# 3636   987.609600  0.535068 -1.144719e-02          1
# 3637   988.636400  0.535209 -1.142835e-02          1
# 3638   989.663800  0.535349 -1.140957e-02          1
# 3639   990.692800  0.535489 -1.139082e-02          1
# 3640   991.722900  0.535629 -1.137213e-02          1
# 3641   992.753500  0.535769 -1.135348e-02          1
# 3642   993.785700  0.535908 -1.133488e-02          1
# 3643   994.818500  0.536046 -1.131633e-02          1
# 3644   995.852800  0.536185 -1.129782e-02          1
# 3645   996.887800  0.536323 -1.127936e-02          1
# 3646   997.924300  0.536460 -1.126094e-02          1
# 3647   998.961900  0.536597 -1.124257e-02          1
# 3648  1000.000000  0.536734 -1.122425e-02          1
#
# [3649 rows x 4 columns]

# %%
def plot_data(x,y1,y2,y3):
    fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')

    plt.title("Plot for transmissability analysis", y=1.08)

    plt.plot(x,y1, label="x-direction")

    plt.plot(x,y2, label="y-direction") 

    
    plt.plot(x,y3, label="z-direction")


    plt.legend(bbox_to_anchor = (0., 1.02, 1., .102), loc=3,ncol=2, mode="expand", borderaxespad=0.)
    
    plt.xlabel("Frequency [Hz]")
    plt.ylabel("Acceleration/Acceleration [mm/s^2/mm/s^2], Scaled to 2G")
    params = {
        'legend.fontsize': 14,
        'legend.handlelength': 2}
    plt.rcParams.update(params)
    plt.show()

# %%
def plot_data3(x,y1,y2,y3):
    fig = plt.figure()
    fig.tight_layout()
    fig.suptitle('Plot for transmissability analysis')

    plt.subplot(1,3,1)
    plt.plot(x,y1, label="x-direction")
    plt.subplot(1,3,2)
    plt.plot(x,y2, label="y-direction")

    plt.subplot(1,3,3)
    plt.plot(x,y3, label="z-direction")

    plt.show()

# %%
def plot_data1(x,y1,y2,y3):
    fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')
    fig, ax1 = plt.subplots()
    ax1.legend(bbox_to_anchor = (0., 1.02, 1., .102), loc=3,ncol=2, mode="expand", borderaxespad=0.)

    ax1.title("Plot for transmissability analysis", y=1.08)

    color = 'tab:red'
    ax1.set_xlabel("Frequency [Hz]")
    ax1.set_ylabel("Acceleration/Acceleration [mm/s^2/mm/s^2], Scaled to 2G",color = color)
    ax1.plot(x,y1, label="x-direction",color = color)
    ax1.plot(x,y2, label="y-direction",color = 'tab:orange')
    

    
    ax1.tick_params(axis = 'y',labelcolor = color)
    
    ax2 = ax1.twinx()
    
    color = 'tab:blue'
    
    ax2.set_ylabel("Acceleration/Acceleration [mm/s^2/mm/s^2], Scaled to 2G", color=color)  # we already handled the x-label with ax1
    ax2.plot(x, y3, color=color,label="z-direction")
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()
    
    
    
    params = {
        'legend.fontsize': 14,
        'legend.handlelength': 2}
    plt.rcParams.update(params)
    plt.show()

# %%
def plot_data2(x,y1,y2,y3):
    
    fig=plt.figure(figsize=(8, 4), dpi= 80, facecolor='w', edgecolor='k')

    plt.title("Plot for transmissability analysis", y=1.08)

    plt.plot(x,y1, label="x-direction")

    plt.plot(x,y2, label="y-direction") 

    
    plt.plot(x,y3, label="z-direction")


    plt.legend(bbox_to_anchor = (0., 1.02, 1., .102), loc=3,ncol=2, mode="expand", borderaxespad=0.)
    
    plt.xlabel("Frequency [Hz]")
    plt.ylabel("Acceleration/Acceleration [mm/s^2/mm/s^2], Scaled to 2G")
    params = {
        'legend.fontsize': 14,
        'legend.handlelength': 2}
    plt.rcParams.update(params)
    plt.show()
